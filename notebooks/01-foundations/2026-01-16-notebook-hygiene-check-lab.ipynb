# %% [markdown]
# # DS2002 Lab 01 — Kaggle Notebook Basics
#
# ## Purpose
# This lab helps you practice:
# - Creating and running a Kaggle Notebook
# - Writing **basic Python** code
# - Committing a notebook and sharing its URL
#
# ---
# ## Submission Instructions
# 1. Download this notebook from GitHub
# 2. Upload/import it into Kaggle
# 3. Complete all **TODO** sections
# 4. Save Version (Commit)
# 5. Submit the **Kaggle Notebook URL** in Canvas

# %% [markdown]
# ## Part 1 — Hello, Kaggle
#
# **TODO:** Replace the string below with a short message introducing yourself.

# %%
message = "Hello! My name is Heer Patel, I am a third-year from Richmond, VA studying Computer Science.\n In my free time I love spending time with my friends and trying new restaurants in Charlottesville!"
print(message)
# Out:
# Hello! My name is Heer Patel, I am a third-year from Richmond, VA studying Computer Science.
#  In my free time I love spending time with my friends and trying new restaurants in Charlottesville!

# %% [markdown]
# ## Part 2 — Variables & Math
#
# **TODO:**
# - Create two numeric variables
# - Add them together
# - Print the result
#
# *Hint:* Use `+` and `print()`

# %%
# TODO You do this here
a, b = 3, 4
result = a + b #do some a + b and set the variables so that print results show something
print(result)
# Out:
# 7

# %% [markdown]
# ## Part 3 — Lists
#
# **TODO:**
# - Create a list of 5 numbers
# - Print the list
# - Print the length of the list
#
# *Hint:* `len()` returns the length of a list

# %%
# TODO
numbers = [1, 5, 2, 49, 3] #list needs to have humbers.
print(numbers)
#print the length of the list using the hint
len(numbers)
# Out:
# [1, 5, 2, 49, 3]
# 5

# %% [markdown]
# ## Part 4 — Looping
#
# **TODO:**
# - Loop over the list from Part 3
# - Print each number multiplied by 2
#
# *Hint:* `for n in numbers:`

# %%
# TODO
for n in numbers:
    print(n * 2)
# Out:
# 2
# 10
# 4
# 98
# 6

# %% [markdown]
# ## Part 5 — Conditionals
#
# **TODO:**
# - Write an `if` statement
# - Print whether a number is positive, negative, or zero
#
# *Hint:* Use `if`, `elif`, `else`

# %%
# TODO
x = 8
if x > 0:
    print("positive")
elif x < 0:
    print("negative")
else:
    print("zero")
# Out:
# positive

# %% [markdown]
# ## Part 6 — Functions
#
# **TODO:**
# - Write a function called `square()`
# - It should return the square of a number
# - Call the function and print the result
#
# *Hint:* `def square(x):`

# %%
# TODO
def square(x):
    return x * x

print(square(5))
# Out:
# 25

# %% [markdown]
# ## Part 7 — Mini Data Exercise
#
# Below is a **small, hard‑coded dataset**.
#
# **TODO:**
# - Compute the average score
# - Print it
#
# *Hint:* `sum()` and `len()`

# %%
scores = [88, 92, 79, 93, 85]

# TODO
average = sum(scores) / len(scores) #you do this
print(average)
# Out:
# 87.4

# %% [markdown]
# ## Final Check
#
# Before submitting:
# - All cells run without errors
# - All TODOs are completed
# - Notebook is committed in Kaggle
#
# **Submit the Kaggle Notebook URL in Canvas.**
#
# You are done.
